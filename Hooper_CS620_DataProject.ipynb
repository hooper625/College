# %% [markdown]
# <a href="https://colab.research.google.com/github/hooper625/College/blob/main/Hooper_CS620_DataProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Erika Hooper<br />
# ehooper001@odu.edu<br />
# https://hooper625.github.io/<br /><br />

# %% [markdown]
# # Raw Data Source
#
#
# URL: https://www.doe.virginia.gov/data-policy-funding/data-reports/statistics-reports/sol-test-pass-rates-other-results
#
# Description: These datasets provide detailed SOL test results at the district level, including subject-area performance, test-by-test breakdowns, and student participation rates. This data can be used to analyze student performance trends across various subjects within specific districts, allowing for comparisons between regions or schools to understand factors that influence academic outcomes.
#
# Below are the first few records of the dataset:

# %%
import pandas as pd
excel_file = '/content/Division_Test_by_level_2023_2024.xlsx'
# Read the CSV file into a DataFrame
df = pd.read_excel(excel_file)
df.head()
# Out:
#    Div Num          Div Name           Subject Grade             Test  \
# 0        1  Accomack County   English: Reading  Gr 3  English Reading
# 1        1  Accomack County   English: Reading  Gr 4  English Reading
# 2        1  Accomack County   English: Reading  Gr 5  English Reading
# 3        1  Accomack County   English: Reading  Gr 6  English Reading
# 4        1  Accomack County   English: Reading  Gr 7  English Reading
#
#   2021-2022 Pass Rate 2022-2023 Pass Rate 2023-2024 Pass Rate  \
# 0                  55                  53                  54
# 1                  62                  65                  63
# 2                  60                  64                  61
# 3                  66                  68                  69
# 4                  71                  63                  66
#
#   2021-2022 Adv Pass Rate 2022-2023 Adv Pass Rate 2023-2024 Adv Pass Rate
# 0                       5                       4                       5
# ...

# %% [markdown]
# End Goal:
#
# *  Correlation Analysis: The objective of this project is to explore the correlation between poverty, household income, and educational attainment levels, and how they influence SOL pass rates across subjects and school divisions. By focusing on key socioeconomic variables, we aim to identify trends and disparities in performance across different districts, with an emphasis on uncovering the impact of poverty and income on educational outcomes.

# %% [markdown]
# # Secondary Datasets

# %% [markdown]
# We plan to enhance this dataset with demographic data from the U.S. Census, specifically focusing on income levels and educational attainment, to provide a deeper understanding of the socioeconomic factors influencing the analysis.

# %% [markdown]
# Secondary Dataset URL: https://data.census.gov/table/DECENNIALSF42000.PCT154?t=Education:Educational%20Attainment:Income%20and%20Poverty&g=040XX00US51$0500000

# %% [markdown]
# # Project Plan

# %% [markdown]
# Project Plan
# Data Exploration: Week 1-3 <br />
# Data Cleaning and Wrangling: Week 4-5 <br />
# Correlation Analysis and Modeling: Week 6-9 <br />
# Visualization and Final Report: Week 10

# %% [markdown]
# 09/02/2024 - JDD - Setup a github repo with all the downloaded data. https://github.com/jddoak/CS620_Data_Project

# %% [markdown]
# 09/03/2024 - JDD - Sent email to ResultsHelp@doe.virginia.gov as 3 of their excel files are corrupt, asking them to replace them.
#
# *   2020-2021 School Test-by-Test
# *   2018-2019 State Test-by-Test
# *   2018-2019 Division Subject-Area
#
# I was able to load the corrupt files into Pandas through some backend file manipulation but cannot open them in Microsoft Office Excel.

# %%
# Step 1: Copy spreadsheets to local
import urllib.request
# Division Spreadsheets
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/
xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2016/2015-16_state_subject.xlsx","2016_state_subject.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2017/2016-17_state_subject.xlsx","2017_state_subject.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2018/2017-2018-state-subject-area.xlsx","2018_state_subject.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2019/state-by-subject-2019.xlsx","2019_state_subject.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2021/2020-2021-state-subject-area.xlsx","2021_state_subject.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2022/state-by-subject-2022.xlsx","2022_state_subject.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2023/state_pass_rates_by_subject_by_stud_group_2022_2023.xlsx","2023_state_subject.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2024/State-Subject_by_Reporting%20Group-_2023-2024.xlsx","2024_state_subject.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2016/2015-16_state_test.xlsx","2016_state_test.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2017/2016-17_state_test.xlsx","2017_state_test.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2018/2017-2018-state-test-by-test.xlsx","2018_state_test.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2019/state-by-test-2019.xlsx","2019_state_test.xlsx") # Corrupt
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2021/2020-2021-state-test-by-test.xlsx","2021_state_test.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2022/state-by-test-2022.xlsx","2022_state_test.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2023/state_pass_rates_by_test_2022_2023.xlsx","2023_state_test.xlsx")
urllib.request.urlretrieve("https://github.com/jddoak/CS620_Data_Project/raw/main/data/2024/State_Test_by_level_2023_2024.xlsx","2024_state_test.xlsx")
# Out:
# ('2024_state_test.xlsx', <http.client.HTTPMessage at 0x7aa9da95cee0>)

# %%
# Step 2: Load Spreadsheets
import numpy as np
import pandas as pd
# Division Spreadsheets
dp21 = pd.read_excel("./2021_div_participation.xlsx","Division by Subject and Group")
dp22 = pd.read_excel("./2022_div_participation.xlsx","Division by Subject and Group")
dp23 = pd.read_excel("./2023_div_participation.xlsx","DIV")
dp24 = pd.read_excel("./2024_div_participation.xlsx","Division")
ds16 = pd.read_excel("./2016_div_subject.xlsx","DIV Subject by Subgroup")
ds17 = pd.read_excel("./2017_div_subject.xlsx","Div by Subject by Subgroup")
ds18 = pd.read_excel("./2018_div_subject.xlsx","Division by Subject & Subgroup")
ds19 = pd.read_excel("./2019_div_subject.xlsx","Division by Subject by Subgroup") # Corrupt
ds21 = pd.read_excel("./2021_div_subject.xlsx","Division by Subject and Group")
ds22 = pd.read_excel("./2022_div_subject.xlsx","Div by Subject by Subgroup")
ds23 = pd.read_excel("./2023_div_subject.xlsx","Div subject by subgroup")
ds24 = pd.read_excel("./2024_div_subject.xlsx","Division")
dt16 = pd.read_excel("./2016_div_test.xlsx","DIV test-level")
dt17 = pd.read_excel("./2017_div_test.xlsx","Div by Test")
dt18 = pd.read_excel("./2018_div_test.xlsx","Division by Test")
dt19 = pd.read_excel("./2019_div_test.xlsx","Division by Test")
dt21 = pd.read_excel("./2021_div_test.xlsx","Division Test-by-Test")
dt22 = pd.read_excel("./2022_div_test.xlsx","Divison by Test")
dt23 = pd.read_excel("./2023_div_test.xlsx","Div by test")
dt24 = pd.read_excel("./2024_div_test.xlsx","Division")
# School Spreadsheets
sp21 = pd.read_excel("./2021_school_participation.xlsx","School by Subject and Group")
sp22 = pd.read_excel("./2022_school_participation.xlsx","School by Subject and Group")
sp23 = pd.read_excel("./2023_school_participation.xlsx","Sheet1")
sp24 = pd.read_excel("./2024_school_participation.xlsx","School")
ss16 = pd.read_excel("./2016_school_subject.xlsx","SCH Subject by Subgroup")
ss17 = pd.read_excel("./2017_school_subject.xlsx","Sch by Subject by Subgroup")
ss18 = pd.read_excel("./2018_school_subject.xlsx","School by Subject and Subgroup")
ss19 = pd.read_excel("./2019_school_subject.xlsx","School by Subject by Subgroup")
ss21 = pd.read_excel("./2021_school_subject.xlsx","School by Subject and Group")
ss22 = pd.read_excel("./2022_school_subject.xlsx","Sch by Subject by Subgroup")
ss23 = pd.read_excel("./2023_school_subject.xlsx","Sch subject by student group")
ss24 = pd.read_excel("./2024_school_subject.xlsx","School")
st16 = pd.read_excel("./2016_school_test.xlsx","SCH test-level")
st17 = pd.read_excel("./2017_school_test.xlsx","Sch by Test")
st18 = pd.read_excel("./2018_school_test.xlsx","School by Test")
st19 = pd.read_excel("./2019_school_test.xlsx","School by Test")
st21 = pd.read_excel("./2021_school_test.xlsx","School Test-by-Test") # Corrupt
st22 = pd.read_excel("./2022_school_test.xlsx","School by Test")
st23 = pd.read_excel("./2023_school_test.xlsx","Sch by test")
st24 = pd.read_excel("./2024_school_test.xlsx","School")
# State Spreadsheets
stp21 = pd.read_excel("./2021_state_participation.xlsx","State by Subject and Group")
stp22 = pd.read_excel("./2022_state_participation.xlsx","State by Subject and Group")
stp23 = pd.read_excel("./2023_state_participation.xlsx","STATE")
stp24 = pd.read_excel("./2024_state_participation.xlsx","State")
sts16 = pd.read_excel("./2016_state_subject.xlsx","STATE Subject by Subgroup")
sts17 = pd.read_excel("./2017_state_subject.xlsx","State by Subject by Subgroup")
sts18 = pd.read_excel("./2018_state_subject.xlsx","Sheet0")
sts19 = pd.read_excel("./2019_state_subject.xlsx","State by Subject by Subgroup")
sts21 = pd.read_excel("./2021_state_subject.xlsx","State by Subject and Group")
sts22 = pd.read_excel("./2022_state_subject.xlsx","State by Subject by Subgroup")
sts23 = pd.read_excel("./2023_state_subject.xlsx","State subject by  student group")
sts24 = pd.read_excel("./2024_state_subject.xlsx","State")
stt16 = pd.read_excel("./2016_state_test.xlsx","STATE test-level")
stt17 = pd.read_excel("./2017_state_test.xlsx","State by Test")
stt18 = pd.read_excel("./2018_state_test.xlsx","Sheet0")
stt19 = pd.read_excel("./2019_state_test.xlsx","State by Test") # Corrupt
stt21 = pd.read_excel("./2021_state_test.xlsx","State Test by Test")
stt22 = pd.read_excel("./2022_state_test.xlsx","State by Test")
stt23 = pd.read_excel("./2023_state_test.xlsx","State by test")
stt24 = pd.read_excel("./2024_state_test.xlsx","State")

# %% [markdown]
# ## 10/5/2024
# ##Since my teammates have dropped off the project I have decided to reduce the data to the 2022/2023 and 2023/2024 school year.
