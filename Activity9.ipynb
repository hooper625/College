# %% [markdown]
# <a href="https://colab.research.google.com/github/hooper625/College/blob/main/Activity9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/brfss.csv')

#cleans the data
def cleanBRFSSFrame():
  #drop column
  df.drop('sex', axis=1, inplace=True)
 #drops NaN values
  df.dropna(inplace=True)

cleanBRFSSFrame()

df.head()

#Find and display 25th, 50th, 70th percentile of the age
def describe():
  count = df['weight2'].count()
  mean = df['weight2'].mean()
  median = df['weight2'].median()
  mode = df['weight2'].mode()[0]
  std= df['weight2'].std()
  min = df['weight2'].min()
  quantile= df['weight2'].quantile([0.25, 0.5, 0.75])
  print("Count: ", count)
  print("Mean: ", mean)
  print("Median: ", median)
  print("Mode: ", mode)
  print("Standard Deviation: ", std)
  print("Minimum: ", min)
  print("Weight2 Quantiles: ", quantile)
  quantile_age= df['age'].quantile([0.25, 0.5, 0.75])
  print("Age Quantiles: ", quantile_age)
  # Create a violin plot for the 'age' column
  sns.violinplot(data=df, y='age')
  plt.title("Violin Plot of Age")
  plt.show()

describe()
# Out:
# Count:  385974
# Mean:  79.0614633957916
# Median:  77.27272727272727
# Mode:  68.18181818181817
# Standard Deviation:  19.514282666029477
# Minimum:  20.0
# Quantiles:  0.25    64.545455
# 0.50    77.272727
# 0.75    90.909091
# Name: weight2, dtype: float64
# Quantiles:  0.25    43.0
# 0.50    55.0
# 0.75    67.0
# Name: age, dtype: float64
